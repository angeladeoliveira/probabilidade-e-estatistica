# %% [markdown]
# <a href="https://colab.research.google.com/github/angeladeoliveira/probabilidade-e-estatistica/blob/master/Lista_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Disciplina: Probabilidade e Estatística
# Aluna: Ângela de Oliveira
# Lista 4

# Exercício 1
# Escreva um programa para ler o número de lados de um polígono regular e a 
# medida do lado (em cm). Calcular e imprimir o seguinte: − Se o número de lados
# for igual a 3 escrever TRIÂNGULO e o valor da área − Se o número de lados for
# igual a 4 escrever QUADRADO e o valor da sua área. − Se o número de lados for
# igual a 5 escrever PENTÁGONO.

'''import math #Importa a biblioteca de matemática para utilizar algumas funções nos cálculos

n_lados = int(input('Digite a quantidade de lados de um polígono regular: ')) #Recebe a quantidade de lados do polígono
t_lados = float(input('Digite a medida do lado do polígono em cm: ')) #Recebe o tamanho dos lados do polígono
if n_lados == 3: #Testa se o polígono é um triângulo
  altura = math.sqrt(t_lados**2 - (t_lados/2)**2) #Calcula a altura do triângulo aplicando-se o teorema de Pitágoras
  area = t_lados*altura/2 #Calcula a área do triângulo
  print('TRIÂNGULO. Área = ', area) #Imprime o tipo e área do polígono
elif n_lados == 4: #Testa se o polígono é um quadrado
  area = t_lados**2 #Calcula a área do quadrado
  print('QUADRADO. Área = ', area) #Imprime o tipo e área do polígono
elif n_lados == 5: #Testa se o polígono é um pentágono
  radians36 = math.radians(36) #Transforma 36 graus em radianos para utilizar na fórmula abaixo
  altura = (t_lados/2)/(math.tan(radians36)) #Calcula a apótema do pentágono através do cálculo da altura dos triângulos que compõe o polígono
  area_triangulo = t_lados*altura/2 #Calcula a área de um dos triângulos que compõe o pentágono
  area = area_triangulo*5 #Calcula a área do pentágono multiplicando por 5 a área de um dos triângulos que compõe o pentágono
  print('PENTÁGONO. Área = ', area) #Imprime o tipo e área do polígono'''

# Exercício 2
# Acrescente as seguintes mensagens à solução do exercício anterior conforme o
# caso. − Caso o número de lados seja inferior a 3 escrever NÃO É UM
# POLÍGONO. − Caso o número de lados seja superior a 5 escrever POLÍGONO
# NÃO IDENTIFICADO.

'''import math #Importa a biblioteca de matemática para utilizar algumas funções nos cálculos

n_lados = int(input('Digite a quantidade de lados de um polígono regular: ')) #Recebe a quantidade de lados do polígono
if n_lados < 3: #Testa se o número de lados é menor que 3
  print('NÃO É UM POLÍGONO') #imprime a mensagem correspondente
elif n_lados == 3: #Testa se o polígono é um triângulo
  t_lados = float(input('Digite a medida do lado do polígono em cm: ')) #Recebe o tamanho dos lados do polígono
  altura = math.sqrt(t_lados**2 - (t_lados/2)**2) #Calcula a altura do triângulo aplicando-se o teorema de Pitágoras
  area = t_lados*altura/2 #Calcula a área do triângulo
  print('TRIÂNGULO. Área = ', area) #Imprime o tipo e área do polígono
elif n_lados == 4: #Testa se o polígono é um quadrado
  t_lados = float(input('Digite a medida do lado do polígono em cm: ')) #Recebe o tamanho dos lados do polígono
  area = t_lados**2 #Calcula a área do quadrado
  print('QUADRADO. Área = ', area) #Imprime o tipo e área do polígono
elif n_lados == 5: #Testa se o polígono é um pentágono
  t_lados = float(input('Digite a medida do lado do polígono em cm: ')) #Recebe o tamanho dos lados do polígono
  radians36 = math.radians(36) #Transforma 36 graus em radianos para utilizar na fórmula abaixo
  altura = (t_lados/2)/(math.tan(radians36)) #Calcula a apótema do pentágono através do cálculo da altura dos triângulos que compõe o polígono
  area_triangulo = t_lados*altura/2 #Calcula a área de um dos triângulos que compõe o pentágono
  area = area_triangulo*5 #Calcula a área do pentágono multiplicando por 5 a área de um dos triângulos que compõe o pentágono
  print('PENTÁGONO. Área = ', area) #Imprime o tipo e área do polígono
else: #Para todos os outros casos, ou seja, se o número de lados é maior que 5
  print('POLÍGONO NÃO IDENTIFICADO') #Imprime a mensagem correspondente'''

# EXERCÍCIO 3
# Escreva um programa para ler 3 valores inteiros e escrever o maior deles.
# Considere que o usuário não informará valores iguais.

'''count = 0 #variável de contagem para ser utilizada no loop while
numeros = [] #lista para receber os valores inseridos pelo usuário

while count < 3: #loop que acontecerá por 3 vezes para receber os 3 números inteiros
  numeros.append(int(input('Digite um número inteiro: '))) #pede o número para o usuário e adiciona na lista criada inicialmente
  count += 1 #adiciona +1 na variável de contagem para que o loop while repita apenas 3 vezes
print('O maior número é ' + str(max(numeros))) #a função max pega o número maior digitado pelo usuário e esse valor é impresso na tela pela função print'''

# EXERCÍCIO 4
# Escreva um programa que leia as medidas dos lados de um triângulo e escreva
# se ele é Equilátero, Isósceles ou Escaleno. Sendo que: − Triângulo Equilátero:
# possui os 3 lados iguais. − Triângulo Isóscele: possui 2 lados iguais. − Triângulo
# Escaleno: possui 3 lados diferentes.

'''lados = [] #lista para armazenar os dados digitados pelo usuário

for _ in range(1,4): #loop for para receber os 3 lados do triângulo, o range começando em 1 e terminando em 4 limita o for a 3 iterações
  lados.append(float(input('Digite a medida do lado ' + str(_) +' do triângulo: '))) #pede para o usuário a medida do lado (de acordo com o número da iteração) e acrescenta a resposta no formato int dentro da lista lados

lados_diferentes = set(lados) #a função set() remove da lista todos os elementos repetidos e o resultado é armazenado na variável lados_diferentes

if len(lados_diferentes) == 1: #se lados_diferentes possuir apenas 1 registro, significa que os 3 lados são iguais e o set removeu os outros 2 números repetidos, ou seja, o triângulo é equilátero
  print('Triângulo Equilátero') #imprime na tela o tipo de triângulo 
elif len(lados_diferentes) == 2: # se a variável lados_diferentes tiver comprimento 2, significa que 2 lados são iguais e o set removeu a medida repetida, restando dois valores, ou seja, o triângulo é isóceles
  print('Triângulo Isóceles') #imprime na tela o tipo de triângulo
else: #como o triângulo só tem 3 lados, se não se encaixar em nenhuma das condições acima, ele só pode ser escaleno (tem 3 lados diferentes e o resultado do comprimento do set é igual a 3, pois nenhum valor é repetido)
  print('Triângulo Escaleno') #imprime na tela o tipo de triângulo'''

# EXERCÍCIO 5
# Escreva um programa que leia o valor de 3 ângulos de um triângulo e escreva se
# o triângulo é Acutângulo, Retângulo ou Obtusângulo. Sendo que: − Triângulo
# Retângulo: possui um ângulo reto. (igual a 90º) − Triângulo Obtusângulo: possui
# um ângulo obtuso. (maior que90º) − Triângulo Acutângulo: possui três ângulos
# agudos. (menor que 90º)

'''angulos = [] #cria uma lista para armazenar o valor dos ângulos

for _ in range(1,4): #loop for para receber os 3 ângulos do triângulo, o range começando em 1 e terminando em 4 limita o for a 3 iterações
  angulos.append(float(input('Digite o valor do ângulo ' + str(_) +' do triângulo (em graus): '))) #pede para o usuário a medida do ângulo (de acordo com o número da iteração) e acrescenta a resposta no formato int dentro da lista angulos

for angulo in angulos: #o loop for percorre os itens da lista angulos
  if angulo == 90: #se o angulo percorrido tiver valor 90, o programa executa a seguinte ação:
    print('O triângulo é Retângulo') #imprime que o triangulo é retângulo pois possui um angulo de 90 graus
    break #o break faz com que o programa saia do loop for e assim finalize a execução
  elif angulo > 90: #se o angulo percorrido tiver valor maior que 90, o programa executa a seguinte ação:
    print('O triângulo é Obtusângulo') #imprime que o triangulo é obtusângulo pois possui um angulo maior que 90 graus
    break #o break faz com que o programa saia do loop for e assim finalize a execução
  else: #para todos os ângulos que não preencherem as condições anteriores, o programa executa a seguinte ação:
    pass #não faz nada, passa para a próxima iteração
  
  if angulo == angulos[-1]: #se o programa não sair do loop for e chegar até aqui é porque todos os ângulos foram menores que 90 graus, pois essa condicional compara se o ângulo percorrido equivale à última posição da lista, se for true é porque todos os angulos já foram testados e caíram na condição else
    print('O triângulo é Acutângulo') #então o programa imprime que é um triângulo acutângulo
    break #e sai do loop for'''

# EXERCÍCIO 6
# Faça um programa para ler um número inteiro e imprimir todos os números de 0
# até o número lido.

'''n = int(input('Digite um número inteiro: ')) #pede para o usuário digitar um número inteiro e armazena na variável n

if n<0: #se o número digitado for negativo, então
  lista = [] #o programa cria uma lista vazia
  for _ in range(n,1): #depois um range que vai do número negativo até 0
    lista.append(_) #e cada número do range é inserido ao final da lista. Se o número digitado for -2, então a lista deve conter [-2, -1, 0] ao final das iterações
  lista.reverse() #ordena a lista do maior para o menor, para que ela comece no zero e termine no número negativo digitado
  for item in lista: #cria um novo loop que irá percorrer todos os itens da lista
    print(item) #imprime cada item da lista na tela de 0 até o número lido
elif n == 0: #se o número digitado for zero, então
  print(n) #imprime o número 0 na tela
else: #para todos os outros casos, ou seja, os números positivos:
  for _ in range(0,n+1): #cria um loop for que vai do número 0 até o número armazenado em n, incluindo o valor de n. Como não estava especificado no enunciado se era ou não para incluir, eu decidi incluir
    print(_) #imprime o valor da iteração do for e dessa forma todos os numeros de 0 a n são impressos na tela'''

# EXERCÍCIO 7
# Solicitar um número entre 1 e 4. Se a pessoas digitar um número diferente,
# mostrar a mensagem "entrada inválida" e solicitar o número novamente. Se
# digitar correto mostrar o número digitado.

'''n = float(input('Digite um número entre 1 e 4: ')) #solicita um número entre 1 e 4 e armazena o valor na variável n

if n < 1 or n > 4: # se o valor for menor que 1 ou maior que 4 (seria uma entrada inválida), entra na condicional e executa a seguinte ação:
  while True: #entra num loop infinito
    n = float(input('Entrada inválida. Digite um número entre 1 e 4: ')) #solicita novamente um número entre 1 e 4 e armazena na variável n
    if n >= 1 and n <= 4: #se o valor for válido, entra na condicional e
      print(n) #o valor é mostrado para o usuário
      break #e sai do loop infinito
      #caso o valor não seja válido, o loop continuará rodando até que o usuário digite um número entre 1 e 4
else: #se o valor digitado inicialmente for válido, ele é apresentado ao usuário
  print(n) #imprime o valor digitado pelo usuário se ele for válido na primeira tentativa'''

# EXERCÍCIO 8
# Fazer um programa que receba vários valores inteiros no teclado (um valor a
# cada iteração) e determine o maior dos colocados desde o inicio do programa. A
# condição de término do programa é quando o usuário digitar zero.

'''lista = [] #cria uma lista para armazenar os valores digitados pelo usuário

while True: #entra em um loop infinito
  lista.append(int(input('Digite um número inteiro ou 0 (zero) para finalizar o programa: '))) #solicita um valor para o usuário e adiciona ao final da lista
  if lista[-1] == 0: #se  último item da lista for igual a 0 (condição de término), executa a seguinte ação:
    print('Programa finalizado') #avisa que o programa foi finalizado
    break #sai do loop infinito e finaliza o programa
  else: #se o último item digitado não for zero, então:
    print(max(lista)) #a função max pega o maior valor da lista (desde seu início) e ele é impresso na tela'''

# EXERCÍCIO 9
# Escreva um programa Python que leia um número inteiro positivo de 4 dígitos,
# calcule e mostre a sua decomposição em unidade, dezena, centena e milhar:
# Exemplo: 8531; unidade = 1 dezena = 3 centena = 5 5 milhar = 8

'''n = input('Digite um número positivo de 4 dígitos: ') #solicita um número para o usuário e armazena na variável n

if n[0] == '+': #caso o número digitado pelo usuário contenha o + no início para indicar que é positivo, o programa executa a seguinte ação:
  n = n.strip('+') #remove o símbolo de + do número

if int(n) <= 0 or len(n) != 4: #se o número for menor ou igual a zero (não positivo) ou tiver menos ou mais que 4 digitos, o programa executa a seguinte ação: 
  while True: #entra em um loop infinito
    n = input('Entrada inválida. Digite um número positivo de 4 dígitos: ') #e solicita uma nova entrada
    
    if n[0] == '+': #caso o número digitado pelo usuário contenha o + no início para indicar que é positivo, o programa executa a seguinte ação:
      n = n.strip('+') #remove o símbolo de + do número

    if int(n) > 0 and len(n) == 4: #se o número for válido, ou seja, for positivo e tiver 4 digitos, então
      break #o programa sai do loop infinito

print(n + '; unidade = ' + n[-1] + ' dezena = ' + n[-2] + ' centena = ' + n[1] + ' milhar = ' + n[0]) #depois de a entrada ser validada, o programa imprime a decomposição em unidade, dezena, centena e milhar
